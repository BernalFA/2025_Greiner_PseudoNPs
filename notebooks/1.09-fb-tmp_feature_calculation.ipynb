# %%
from rdkit.Chem import Descriptors, rdMolDescriptors

# %%
needed = [
    "GetNumAtoms",
    "ExactMolWt",
    "NumRings",
    "NumAromaticRings",
    "NumAliphaticRings",
    "NumLipinskiHBD",
    "NumLipinskiHBA",
    "MolLogP",
    "TPSA",
    "NumRotatableBonds",
    "GetAtomicNum",
    "fr_halogen",
    "NumBridgeheadAtoms",
    "FractionCSP3",
]

# %%
max([len(n) for n in needed])
# Out:
# 18

# %%
rdkit_desc_names = [d[0] for d in Descriptors._descList]

for n in needed:
    if n in rdkit_desc_names:
        print(f"{n:19}: ok")
    else:
        print(f"{n:19}: no")
# Out:
# GetNumAtoms        : no
# ExactMolWt         : ok
# NumRings           : no
# NumAromaticRings   : ok
# NumAliphaticRings  : ok
# NumLipinskiHBD     : no
# NumLipinskiHBA     : no
# MolLogP            : ok
# TPSA               : ok
# NumRotatableBonds  : ok
# GetAtomicNum       : no
# fr_halogen         : ok
# NumBridgeheadAtoms : ok
# FractionCSP3       : ok

# %%
def search_desc(string):
    for d in rdkit_desc_names:
        if string in d:
            print(d)

# %%
search_desc("Ring")
# Out:
# NumAliphaticRings
# NumAromaticRings
# NumSaturatedRings
# RingCount

# %%
search_desc("ipinski")

# %%
search_desc("Num")
# Out:
# NumValenceElectrons
# NumRadicalElectrons
# NumAliphaticCarbocycles
# NumAliphaticHeterocycles
# NumAliphaticRings
# NumAmideBonds
# NumAromaticCarbocycles
# NumAromaticHeterocycles
# NumAromaticRings
# NumAtomStereoCenters
# NumBridgeheadAtoms
# NumHAcceptors
# NumHDonors
# NumHeteroatoms
# NumHeterocycles
# NumRotatableBonds
# NumSaturatedCarbocycles
# NumSaturatedHeterocycles
# NumSaturatedRings
# NumSpiroAtoms
# NumUnspecifiedAtomStereoCenters

# %%
desc = [
    "ExactMolWt",
    "RingCount",
    "NumAromaticRings",
    "NumAliphaticRings",
    "NumHDonors",
    "NumHAcceptors",
    "MolLogP",
    "TPSA",
    "NumRotatableBonds",
    "fr_halogen",
    "NumBridgeheadAtoms",
    "FractionCSP3",
]

# %%
len(Descriptors._descList)
# Out:
# 217

# %%
tmp = dict(Descriptors._descList)
len(tmp)
# Out:
# 217

# %%
tmp
# Out:
# {'MaxAbsEStateIndex': <function rdkit.Chem.EState.EState.MaxAbsEStateIndex(mol, force=1)>,
#  'MaxEStateIndex': <function rdkit.Chem.EState.EState.MaxEStateIndex(mol, force=1)>,
#  'MinAbsEStateIndex': <function rdkit.Chem.EState.EState.MinAbsEStateIndex(mol, force=1)>,
#  'MinEStateIndex': <function rdkit.Chem.EState.EState.MinEStateIndex(mol, force=1)>,
#  'qed': <function rdkit.Chem.QED.qed(mol, w=QEDproperties(MW=0.66, ALOGP=0.46, HBA=0.05, HBD=0.61, PSA=0.06, ROTB=0.65, AROM=0.48, ALERTS=0.95), qedProperties=None)>,
#  'SPS': <function rdkit.Chem.SpacialScore.SPS(mol, normalize=True)>,
#  'MolWt': <function rdkit.Chem.Descriptors.<lambda>(*x, **y)>,
#  'HeavyAtomMolWt': <function rdkit.Chem.Descriptors.HeavyAtomMolWt(x)>,
#  'ExactMolWt': <function rdkit.Chem.Descriptors.<lambda>(*x, **y)>,
#  'NumValenceElectrons': <function rdkit.Chem.Descriptors.NumValenceElectrons(mol)>,
#  'NumRadicalElectrons': <function rdkit.Chem.Descriptors.NumRadicalElectrons(mol)>,
#  'MaxPartialCharge': <function rdkit.Chem.Descriptors.MaxPartialCharge(mol, force=False)>,
#  'MinPartialCharge': <function rdkit.Chem.Descriptors.MinPartialCharge(mol, force=False)>,
#  'MaxAbsPartialCharge': <function rdkit.Chem.Descriptors.MaxAbsPartialCharge(mol, force=False)>,
#  'MinAbsPartialCharge': <function rdkit.Chem.Descriptors.MinAbsPartialCharge(mol, force=False)>,
#  'FpDensityMorgan1': <function rdkit.Chem.Descriptors.FpDensityMorgan1(x)>,
#  'FpDensityMorgan2': <function rdkit.Chem.Descriptors.FpDensityMorgan2(x)>,
#  'FpDensityMorgan3': <function rdkit.Chem.Descriptors.FpDensityMorgan3(x)>,
#  'BCUT2D_MWHI': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MWHI(mol, index=0)>,
#  'BCUT2D_MWLOW': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MWLOW(mol, index=1)>,
#  'BCUT2D_CHGHI': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_CHGHI(mol, index=2)>,
#  'BCUT2D_CHGLO': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_CHGLO(mol, index=3)>,
#  'BCUT2D_LOGPHI': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_LOGPHI(mol, index=4)>,
#  'BCUT2D_LOGPLOW': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_LOGPLOW(mol, index=5)>,
#  'BCUT2D_MRHI': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MRHI(mol, index=6)>,
#  'BCUT2D_MRLOW': <function rdkit.Chem.ChemUtils.DescriptorUtilities.BCUT2D_MRLOW(mol, index=7)>,
#  'AvgIpc': <function rdkit.Chem.GraphDescriptors.AvgIpc(mol, dMat=None, forceDMat=False)>,
#  'BalabanJ': <function rdkit.Chem.GraphDescriptors.BalabanJ(mol, dMat=None, forceDMat=0)>,
#  'BertzCT': <function rdkit.Chem.GraphDescriptors.BertzCT(mol, cutoff=100, dMat=None, forceDMat=1)>,
#  'Chi0': <function rdkit.Chem.GraphDescriptors.Chi0(mol)>,
#  'Chi0n': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi0v': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi1': <function rdkit.Chem.GraphDescriptors.Chi1(mol)>,
#  'Chi1n': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi1v': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi2n': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi2v': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi3n': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi3v': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi4n': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Chi4v': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'HallKierAlpha': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Ipc': <function rdkit.Chem.GraphDescriptors.Ipc(mol, avg=False, dMat=None, forceDMat=False)>,
#  'Kappa1': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Kappa2': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'Kappa3': <function rdkit.Chem.GraphDescriptors.<lambda>(x)>,
#  'LabuteASA': <function rdkit.Chem.MolSurf.<lambda>(*x, **y)>,
#  'PEOE_VSA1': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=0)>,
#  'PEOE_VSA10': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=9)>,
#  'PEOE_VSA11': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=10)>,
#  'PEOE_VSA12': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=11)>,
#  'PEOE_VSA13': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=12)>,
#  'PEOE_VSA14': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=13)>,
#  'PEOE_VSA2': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=1)>,
#  'PEOE_VSA3': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=2)>,
#  'PEOE_VSA4': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=3)>,
#  'PEOE_VSA5': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=4)>,
#  'PEOE_VSA6': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=5)>,
#  'PEOE_VSA7': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=6)>,
#  'PEOE_VSA8': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=7)>,
#  'PEOE_VSA9': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=8)>,
#  'SMR_VSA1': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=0)>,
#  'SMR_VSA10': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=9)>,
#  'SMR_VSA2': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=1)>,
#  'SMR_VSA3': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=2)>,
#  'SMR_VSA4': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=3)>,
#  'SMR_VSA5': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=4)>,
#  'SMR_VSA6': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=5)>,
#  'SMR_VSA7': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=6)>,
#  'SMR_VSA8': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=7)>,
#  'SMR_VSA9': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=8)>,
#  'SlogP_VSA1': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=0)>,
#  'SlogP_VSA10': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=9)>,
#  'SlogP_VSA11': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=10)>,
#  'SlogP_VSA12': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=11)>,
#  'SlogP_VSA2': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=1)>,
#  'SlogP_VSA3': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=2)>,
#  'SlogP_VSA4': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=3)>,
#  'SlogP_VSA5': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=4)>,
#  'SlogP_VSA6': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=5)>,
#  'SlogP_VSA7': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=6)>,
#  'SlogP_VSA8': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=7)>,
#  'SlogP_VSA9': <function rdkit.Chem.MolSurf._InstallDescriptors.<locals>.<lambda>(x, y=8)>,
#  'TPSA': <function rdkit.Chem.MolSurf.<lambda>(*x, **y)>,
#  'EState_VSA1': <function rdkit.Chem.EState.EState_VSA.EState_VSA1(mol)>,
#  'EState_VSA10': <function rdkit.Chem.EState.EState_VSA.EState_VSA10(mol)>,
#  'EState_VSA11': <function rdkit.Chem.EState.EState_VSA.EState_VSA11(mol)>,
#  'EState_VSA2': <function rdkit.Chem.EState.EState_VSA.EState_VSA2(mol)>,
#  'EState_VSA3': <function rdkit.Chem.EState.EState_VSA.EState_VSA3(mol)>,
#  'EState_VSA4': <function rdkit.Chem.EState.EState_VSA.EState_VSA4(mol)>,
#  'EState_VSA5': <function rdkit.Chem.EState.EState_VSA.EState_VSA5(mol)>,
#  'EState_VSA6': <function rdkit.Chem.EState.EState_VSA.EState_VSA6(mol)>,
#  'EState_VSA7': <function rdkit.Chem.EState.EState_VSA.EState_VSA7(mol)>,
#  'EState_VSA8': <function rdkit.Chem.EState.EState_VSA.EState_VSA8(mol)>,
#  'EState_VSA9': <function rdkit.Chem.EState.EState_VSA.EState_VSA9(mol)>,
#  'VSA_EState1': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState10': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState2': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState3': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState4': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState5': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState6': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState7': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState8': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'VSA_EState9': <function rdkit.Chem.EState.EState_VSA._descriptor_VSA_EState.<locals>.VSA_EState_bin(mol)>,
#  'FractionCSP3': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a8e0>)>,
#  'HeavyAtomCount': <function rdkit.Chem.Lipinski.HeavyAtomCount(mol)>,
#  'NHOHCount': <function rdkit.Chem.Lipinski.<lambda>(x)>,
#  'NOCount': <function rdkit.Chem.Lipinski.<lambda>(x)>,
#  'NumAliphaticCarbocycles': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a6b0>)>,
#  'NumAliphaticHeterocycles': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a640>)>,
#  'NumAliphaticRings': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a5d0>)>,
#  'NumAmideBonds': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a870>)>,
#  'NumAromaticCarbocycles': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a480>)>,
#  'NumAromaticHeterocycles': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a410>)>,
#  'NumAromaticRings': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a2c0>)>,
#  'NumAtomStereoCenters': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62bb90>)>,
#  'NumBridgeheadAtoms': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62bb20>)>,
#  'NumHAcceptors': <function rdkit.Chem.Lipinski.<lambda>(x)>,
#  'NumHDonors': <function rdkit.Chem.Lipinski.<lambda>(x)>,
#  'NumHeteroatoms': <function rdkit.Chem.Lipinski.<lambda>(x)>,
#  'NumHeterocycles': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a3a0>)>,
#  'NumRotatableBonds': <function rdkit.Chem.Lipinski.<lambda>(x)>,
#  'NumSaturatedCarbocycles': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a560>)>,
#  'NumSaturatedHeterocycles': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a4f0>)>,
#  'NumSaturatedRings': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62a330>)>,
#  'NumSpiroAtoms': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62bab0>)>,
#  'NumUnspecifiedAtomStereoCenters': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62bc00>)>,
#  'Phi': <function rdkit.Chem.Lipinski.<lambda>(x, y=<Boost.Python.function object at 0x603ddb62b960>)>,
#  'RingCount': <function rdkit.Chem.Lipinski.<lambda>(x)>,
#  'MolLogP': <function rdkit.Chem.Crippen.<lambda>(*x, **y)>,
#  'MolMR': <function rdkit.Chem.Crippen.<lambda>(*x, **y)>,
#  'fr_Al_COO': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59cb0>)>,
#  'fr_Al_OH': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59af0>)>,
#  'fr_Al_OH_noTert': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bae0>)>,
#  'fr_ArN': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bed0>)>,
#  'fr_Ar_COO': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59d20>)>,
#  'fr_Ar_N': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a1f0>)>,
#  'fr_Ar_NH': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a260>)>,
#  'fr_Ar_OH': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59a80>)>,
#  'fr_COO': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59d90>)>,
#  'fr_COO2': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59e00>)>,
#  'fr_C_O': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad599a0>)>,
#  'fr_C_O_noCOO': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59a10>)>,
#  'fr_C_S': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5ad50>)>,
#  'fr_HOCCN': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad680b0>)>,
#  'fr_Imine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a340>)>,
#  'fr_NH0': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a180>)>,
#  'fr_NH1': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a110>)>,
#  'fr_NH2': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a0a0>)>,
#  'fr_N_O': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a570>)>,
#  'fr_Ndealkylation1': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bd80>)>,
#  'fr_Ndealkylation2': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bdf0>)>,
#  'fr_Nhpyrrole': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a960>)>,
#  'fr_SH': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5ace0>)>,
#  'fr_aldehyde': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59fc0>)>,
#  'fr_alkyl_carbamate': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5be60>)>,
#  'fr_alkyl_halide': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5ac00>)>,
#  'fr_allylic_oxid': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bd10>)>,
#  'fr_amide': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a7a0>)>,
#  'fr_amidine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a880>)>,
#  'fr_aniline': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a2d0>)>,
#  'fr_aryl_methyl': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bc30>)>,
#  'fr_azide': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a730>)>,
#  'fr_azo': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a6c0>)>,
#  'fr_barbitur': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5af10>)>,
#  'fr_benzene': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b6f0>)>,
#  'fr_benzodiazepine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bbc0>)>,
#  'fr_bicyclic': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b680>)>,
#  'fr_diazo': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a650>)>,
#  'fr_dihydropyridine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b8b0>)>,
#  'fr_epoxide': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b5a0>)>,
#  'fr_ester': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59c40>)>,
#  'fr_ether': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59ee0>)>,
#  'fr_furan': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b0d0>)>,
#  'fr_guanido': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a8f0>)>,
#  'fr_halogen': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5ab90>)>,
#  'fr_hdrzine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a420>)>,
#  'fr_hdrzone': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a490>)>,
#  'fr_imidazole': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b060>)>,
#  'fr_imide': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a9d0>)>,
#  'fr_isocyan': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5aa40>)>,
#  'fr_isothiocyan': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5aab0>)>,
#  'fr_ketone': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59e70>)>,
#  'fr_ketone_Topliss': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bf40>)>,
#  'fr_lactam': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b450>)>,
#  'fr_lactone': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b4c0>)>,
#  'fr_methoxy': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59bd0>)>,
#  'fr_morpholine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b3e0>)>,
#  'fr_nitrile': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a3b0>)>,
#  'fr_nitro': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a5e0>)>,
#  'fr_nitro_arom': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b840>)>,
#  'fr_nitro_arom_nonortho': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b920>)>,
#  'fr_nitroso': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a500>)>,
#  'fr_oxazole': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b220>)>,
#  'fr_oxime': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59b60>)>,
#  'fr_para_hydroxylation': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5bb50>)>,
#  'fr_phenol': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad59f50>)>,
#  'fr_phenol_noOrthoHbond': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5ba00>)>,
#  'fr_phos_acid': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b760>)>,
#  'fr_phos_ester': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b7d0>)>,
#  'fr_piperdine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b300>)>,
#  'fr_piperzine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b370>)>,
#  'fr_priamide': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a810>)>,
#  'fr_prisulfonamd': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5aea0>)>,
#  'fr_pyridine': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b290>)>,
#  'fr_quatN': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5a030>)>,
#  'fr_sulfide': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5ac70>)>,
#  'fr_sulfonamd': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5adc0>)>,
#  'fr_sulfone': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5ae30>)>,
#  'fr_term_acetylene': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5af80>)>,
#  'fr_tetrazole': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b530>)>,
#  'fr_thiazole': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b1b0>)>,
#  'fr_thiocyan': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5ab20>)>,
#  'fr_thiophene': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b140>)>,
#  'fr_unbrch_alkane': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5b610>)>,
#  'fr_urea': <function rdkit.Chem.Fragments._LoadPatterns.<locals>.<lambda>(mol, countUnique=True, pattern=<rdkit.Chem.rdchem.Mol object at 0x7081bad5aff0>)>}

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from src.utils import calculate_selected_descriptors

# %%
import pandas as pd

PATH = Path.cwd().parent / "data" / "interim"
df = pd.read_csv(PATH / "compounds_GreinerL_cleaned.csv")
df.head()
# Out:
#   cmpd_id                                        taut_smiles
# 0      5a  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ccccc...
# 1      5b  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ccc(F...
# 2      5c  CCOC(=O)N1CC[C@@]2(c3ccc(OC)c(OC)c3)Cc3[nH]c4c...
# 3      5d  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ccc(B...
# 4      5e  CCOC(=O)N1CCC2(c3cccc(OC)c3)Cc3[nH]c4ccc(OC(F)...

# %%
from rdkit import Chem
from rdkit.Chem import PandasTools

PandasTools.AddMoleculeColumnToFrame(df, smilesCol="taut_smiles")

# %%
calculate_selected_descriptors(df["ROMol"][0])
# Out:
# {'ExactMolWt': 420.204907376,
#  'RingCount': 5,
#  'NumAromaticRings': 3,
#  'NumAliphaticRings': 2,
#  'NumHDonors': 1,
#  'NumHAcceptors': 4,
#  'MolLogP': 4.452500000000003,
#  'TPSA': 63.79,
#  'NumRotatableBonds': 4,
#  'fr_halogen': 0,
#  'NumBridgeheadAtoms': 0,
#  'FractionCSP3': 0.4,
#  'NumOxygen': 4,
#  'NumNitrogen': 2,
#  'LipinskiViolations': 0,
#  'VeberViolations': 0}

# %%
df = pd.concat((df,df["ROMol"].apply(calculate_selected_descriptors).apply(pd.Series)), axis=1)

# %%
df
# Out:
#    cmpd_id                                        taut_smiles  \
# 0       5a  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ccccc...
# 1       5b  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ccc(F...
# 2       5c  CCOC(=O)N1CC[C@@]2(c3ccc(OC)c(OC)c3)Cc3[nH]c4c...
# 3       5d  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ccc(B...
# 4       5e  CCOC(=O)N1CCC2(c3cccc(OC)c3)Cc3[nH]c4ccc(OC(F)...
# 5       5f  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ccc(S...
# 6       5g  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ccc(C...
# 7       5h  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3[nH]c4ncccc...
# 8       5i      CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3ncccc3CC12
# 9       5j   CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3nccc(C)c3CC12
# 10      5k  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3nccc(-c4ccc...
# 11      5l  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)CC3(CCC12)NCCc...
# 12      5m  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3nc4ccc(Br)c...
# 13      5n  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)c3c([nH]c4cccc...
# 14      5o  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)c3c([nH]c4ccc(...
# 15      5p  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)c3c([nH]c4ccc(...
# 16      5q  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)c3c([nH]c4ccc(...
# 17      5r  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3nccc(-c4ccc...
# 18      5s  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3nccc(-c4ccc...
# 19      5t  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3nccc(-c4ccc...
# 20      5u  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3nccc(-c4ccc...
# 21      5v  CCOC(=O)N1CCC2(c3ccc(OC)c(OC)c3)Cc3nccc(-c4cc(...
#
#                                                ROMol  ExactMolWt  RingCount  \
# 0   <rdkit.Chem.rdchem.Mol object at 0x7081b81b0900>  420.204907        5.0
# 1   <rdkit.Chem.rdchem.Mol object at 0x7081b81b1930>  438.195486        5.0
# 2   <rdkit.Chem.rdchem.Mol object at 0x7081b81b1850>  454.165935        5.0
# 3   <rdkit.Chem.rdchem.Mol object at 0x7081b3843f40>  498.115419        5.0
# 4   <rdkit.Chem.rdchem.Mol object at 0x7081b38ac0b0>  474.176642        5.0
# 5   <rdkit.Chem.rdchem.Mol object at 0x7081b38ac120>  499.177707        5.0
# 6   <rdkit.Chem.rdchem.Mol object at 0x7081b38ac190>  464.194737        5.0
# 7   <rdkit.Chem.rdchem.Mol object at 0x7081b38ac200>  421.200156        5.0
# 8   <rdkit.Chem.rdchem.Mol object at 0x7081b38ac270>  382.189257        4.0
# 9   <rdkit.Chem.rdchem.Mol object at 0x7081b38ac2e0>  396.204907        4.0
# 10  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac350>  458.220557        5.0
# 11  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac3c0>  519.273321        6.0
# 12  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac430>  510.115419        5.0
# 13  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac4a0>  420.204907        5.0
# 14  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac510>  454.165935        5.0
# 15  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac580>  498.115419        5.0
# 16  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac5f0>  450.215472        5.0
# 17  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac660>  472.236208        5.0
# 18  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac6d0>  492.181585        5.0
# 19  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac740>  488.231122        5.0
# 20  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac7b0>  518.241687        5.0
# 21  <rdkit.Chem.rdchem.Mol object at 0x7081b38ac820>  548.252251        5.0
#
#     NumAromaticRings  NumAliphaticRings  NumHDonors  NumHAcceptors  MolLogP  \
# 0                3.0                2.0         1.0            4.0  4.45250
# 1                3.0                2.0         1.0            4.0  4.59160
# 2                3.0                2.0         1.0            4.0  5.10590
# 3                3.0                2.0         1.0            4.0  5.21500
# 4                3.0                2.0         1.0            4.0  5.34250
# 5                3.0                2.0         2.0            6.0  3.09990
# 6                3.0                2.0         2.0            5.0  4.15070
# 7                3.0                2.0         1.0            5.0  3.84750
# 8                2.0                2.0         0.0            5.0  3.36620
# 9                2.0                2.0         0.0            5.0  3.67462
# 10               3.0                2.0         0.0            5.0  5.03320
# 11               3.0                3.0         2.0            6.0  4.88740
# 12               3.0                2.0         0.0            5.0  5.28190
# 13               3.0                2.0         1.0            4.0  4.64820
# 14               3.0                2.0         1.0            4.0  5.30160
# 15               3.0                2.0         1.0            4.0  5.41070
# 16               3.0                2.0         1.0            5.0  4.65680
# 17               3.0                2.0         0.0            5.0  5.34162
# 18               3.0                2.0         0.0            5.0  5.68660
# 19               3.0                2.0         0.0            6.0  5.04180
# 20               3.0                2.0         0.0            7.0  5.05040
# 21               3.0                2.0         0.0            8.0  5.05900
#
#       TPSA  NumRotatableBonds  fr_halogen  NumBridgeheadAtoms  FractionCSP3  \
# 0    63.79                4.0         0.0                 0.0      0.400000
# 1    63.79                4.0         1.0                 0.0      0.400000
# 2    63.79                4.0         1.0                 0.0      0.400000
# 3    63.79                4.0         1.0                 0.0      0.400000
# 4    63.79                4.0         3.0                 0.0      0.400000
# 5   123.95                5.0         0.0                 0.0      0.400000
# 6   101.09                5.0         0.0                 0.0      0.384615
# 7    76.68                4.0         0.0                 0.0      0.416667
# 8    60.89                4.0         0.0                 0.0      0.454545
# 9    60.89                4.0         0.0                 0.0      0.478261
# 10   60.89                5.0         0.0                 0.0      0.357143
# 11   85.05                5.0         0.0                 0.0      0.500000
# 12   60.89                4.0         1.0                 0.0      0.384615
# 13   63.79                4.0         0.0                 0.0      0.400000
# 14   63.79                4.0         1.0                 0.0      0.400000
# 15   63.79                4.0         1.0                 0.0      0.400000
# 16   73.02                5.0         0.0                 0.0      0.423077
# 17   60.89                5.0         0.0                 0.0      0.379310
# 18   60.89                5.0         1.0                 0.0      0.357143
# 19   70.12                6.0         0.0                 0.0      0.379310
# 20   79.35                7.0         0.0                 0.0      0.400000
# 21   88.58                8.0         0.0                 0.0      0.419355
#
#     NumOxygen  NumNitrogen  LipinskiViolations  VeberViolations
# 0         4.0          2.0                 0.0              0.0
# 1         4.0          2.0                 0.0              0.0
# 2         4.0          2.0                 1.0              0.0
# 3         4.0          2.0                 1.0              0.0
# 4         4.0          2.0                 1.0              0.0
# 5         6.0          3.0                 0.0              0.0
# 6         6.0          2.0                 0.0              0.0
# 7         4.0          3.0                 0.0              0.0
# 8         4.0          2.0                 0.0              0.0
# 9         4.0          2.0                 0.0              0.0
# 10        4.0          2.0                 1.0              0.0
# 11        5.0          3.0                 1.0              0.0
# 12        4.0          2.0                 2.0              0.0
# 13        4.0          2.0                 0.0              0.0
# 14        4.0          2.0                 1.0              0.0
# 15        4.0          2.0                 1.0              0.0
# 16        5.0          2.0                 0.0              0.0
# 17        4.0          2.0                 1.0              0.0
# 18        4.0          2.0                 1.0              0.0
# 19        5.0          2.0                 1.0              0.0
# 20        6.0          2.0                 2.0              0.0
# 21        7.0          2.0                 2.0              0.0

# %%
# taken from https://github.com/rdkit/rdkit/issues/2279

import os
from rdkit.Chem import RDConfig

sys.path.append(RDConfig.RDContribDir)

from NP_Score import npscorer

# %%
fscore = npscorer.readNPModel()
def score_np(mol):
    return npscorer.scoreMol(mol, fscore)
# Out:
# reading NP model ...
# model in

# %%
df["NP_likeness"] = df["ROMol"].apply(score_np)

# %%
from rdkit.Chem import QED

df["QED"] = df["ROMol"].apply(QED.default)
